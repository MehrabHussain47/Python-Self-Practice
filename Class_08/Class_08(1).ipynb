# %% [markdown]
# <a href="https://colab.research.google.com/github/MehrabHussain47/Python-Self-Practice/blob/master/Class_08(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ccfd5c66-88db-4b86-bfd4-1a32fc377214" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ccfd5c66-88db-4b86-bfd4-1a32fc377214">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("datasets-5.csv")
# df = pd.read_csv("datasets-5.csv", sheet_name = "datasets-5") # if I have multiple sheets

# %%
df  # df is data-frame
# Out:
#        age  sex  chest pain type  resting bp s  cholesterol  \
# 0     40.0    1                2           140        289.0
# 1     49.0    0                3           160        180.0
# 2     37.0    1                2           130        283.0
# 3     48.0    0                4           138        214.0
# 4     54.0    1                3           150        195.0
# ...    ...  ...              ...           ...          ...
# 1185  45.0    1                1           110        264.0
# 1186  68.0    1                4           144        193.0
# 1187  57.0    1                4           130        131.0
# 1188  57.0    0                2           130        236.0
# 1189  38.0    1                3           138        175.0
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0           172.0                0
# 1                       0            0           156.0                0
# ...

# %%
df.head() # only shows the first 5 row of dataframe
# Out:
#     age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0  40.0    1                2           140        289.0                    0
# 1  49.0    0                3           160        180.0                    0
# 2  37.0    1                2           130        283.0                    0
# 3  48.0    0                4           138        214.0                    0
# 4  54.0    1                3           150        195.0                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0           172.0                0      0.0         1       0
# 1            0           156.0                0      1.0         2       1
# 2            1            98.0                0      0.0         1       0
# 3            0           108.0                1      NaN         2       1
# 4            0           122.0                0      0.0         1       0

# %%
df.head(10)
# Out:
#     age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0  40.0    1                2           140        289.0                    0
# 1  49.0    0                3           160        180.0                    0
# 2  37.0    1                2           130        283.0                    0
# 3  48.0    0                4           138        214.0                    0
# 4  54.0    1                3           150        195.0                    0
# 5  39.0    1                3           120        339.0                    0
# 6  45.0    0                2           130        237.0                    0
# 7  54.0    1                2           110        208.0                    0
# 8  37.0    1                4           140        207.0                    0
# 9  48.0    0                2           120        284.0                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# ...

# %%
ages = pd.Series(df['age'])

# %%
print("Ages Series: ")
print(ages)
# Out:
# Ages Series:
# 0       40.0
# 1       49.0
# 2       37.0
# 3       48.0
# 4       54.0
#         ...
# 1185    45.0
# 1186    68.0
# 1187    57.0
# 1188    57.0
# 1189    38.0
# Name: age, Length: 1190, dtype: float64

# %%
print(df)
# Out:
#        age  sex  chest pain type  resting bp s  cholesterol  \
# 0     40.0    1                2           140        289.0
# 1     49.0    0                3           160        180.0
# 2     37.0    1                2           130        283.0
# 3     48.0    0                4           138        214.0
# 4     54.0    1                3           150        195.0
# ...    ...  ...              ...           ...          ...
# 1185  45.0    1                1           110        264.0
# 1186  68.0    1                4           144        193.0
# 1187  57.0    1                4           130        131.0
# 1188  57.0    0                2           130        236.0
# 1189  38.0    1                3           138        175.0
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0           172.0                0
# 1                       0            0           156.0                0
# ...

# %%
df.tail()
# Out:
#        age  sex  chest pain type  resting bp s  cholesterol  \
# 1185  45.0    1                1           110        264.0
# 1186  68.0    1                4           144        193.0
# 1187  57.0    1                4           130        131.0
# 1188  57.0    0                2           130        236.0
# 1189  38.0    1                3           138        175.0
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 1185                    0            0           132.0                0
# 1186                    1            0           141.0                0
# 1187                    0            0           115.0                1
# 1188                    0            2           174.0                0
# 1189                    0            0           173.0                0
#
#       oldpeak  ST slope  target
# 1185      1.2         2       1
# 1186      3.4         2       1
# 1187      1.2         2       1
# 1188      0.0         2       1
# ...

# %%
print(df.loc[df["age"] <= 40 ])
# Out:
#        age  sex  chest pain type  resting bp s  cholesterol  \
# 0     40.0    1                2           140        289.0
# 2     37.0    1                2           130        283.0
# 5     39.0    1                3           120        339.0
# 8     37.0    1                4           140        207.0
# 10    37.0    0                3           130        211.0
# ...    ...  ...              ...           ...          ...
# 1112  34.0    0                2           118        210.0
# 1155  40.0    1                4           152        223.0
# 1164  39.0    0                3           138        220.0
# 1170  35.0    1                2           122        192.0
# 1189  38.0    1                3           138        175.0
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0           172.0                0
# 2                       0            1            98.0                0
# ...

# %%
df.shape
# Out:
# (1190, 12)

# %%
df['age'] = pd.to_numeric(df['age'], errors='coerce') # String to interger conversion we use coerce for if there is a string value other than numeric value than transfer to NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  1183 non-null   float64
#  1   sex                  1190 non-null   int64
#  2   chest pain type      1190 non-null   int64
#  3   resting bp s         1190 non-null   int64
#  4   cholesterol          1189 non-null   float64
#  5   fasting blood sugar  1190 non-null   int64
#  6   resting ecg          1190 non-null   int64
#  7   max heart rate       1189 non-null   float64
#  8   exercise angina      1190 non-null   int64
#  9   oldpeak              1189 non-null   float64
#  10  ST slope             1190 non-null   int64
#  11  target               1190 non-null   int64
# dtypes: float64(4), int64(8)
# memory usage: 111.7 KB

# %%
df['age'].fillna(df['age'].mean(), inplace=True) # fill the empty age value with mean value
# Out:
# <ipython-input-89-593d1087b194>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].mean(), inplace=True) # fill the empty age value with mean value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  1183 non-null   float64
#  1   sex                  1190 non-null   int64
#  2   chest pain type      1190 non-null   int64
#  3   resting bp s         1190 non-null   int64
#  4   cholesterol          1189 non-null   float64
#  5   fasting blood sugar  1190 non-null   int64
#  6   resting ecg          1190 non-null   int64
#  7   max heart rate       1189 non-null   float64
#  8   exercise angina      1190 non-null   int64
#  9   oldpeak              1189 non-null   float64
#  10  ST slope             1190 non-null   int64
#  11  target               1190 non-null   int64
# dtypes: float64(4), int64(8)
# memory usage: 111.7 KB

# %%
df['sex'].fillna('Unknown', inplace=True ) # filling the empty sex value with 'Unknown'
# Out:
# <ipython-input-90-933ca49776fb>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['sex'].fillna('Unknown', inplace=True ) # filling the empty sex value with 'Unknown'

# %%
df.drop_duplicates(inplace=True) # duplicate row drop hobe

# %%
df.shape
# Out:
# (919, 12)

# %%
print(df['age'].mean())
# Out:
# 53.549780762470135

# %%
print(df['age'].median())
# Out:
# 54.0

# %%
print(df['age'].mode()[0])
# Out:
# 54.0

# %%
df.corr()
# Out:
#                           age       sex  chest pain type  resting bp s  \
# age                  1.000000  0.058049         0.164143      0.253288
# sex                  0.058049  1.000000         0.170574      0.005167
# chest pain type      0.164143  0.170574         1.000000      0.022178
# resting bp s         0.253288  0.005167         0.022178      1.000000
# cholesterol         -0.092966 -0.201771        -0.137800      0.101361
# fasting blood sugar  0.196639  0.115807         0.113732      0.070026
# resting ecg          0.208906 -0.021919         0.028770      0.097462
# max heart rate      -0.374716 -0.190441        -0.344348     -0.112152
# exercise angina      0.212240  0.187570         0.414108      0.154948
# oldpeak              0.257265  0.108683         0.245536      0.164608
# ST slope             0.260792  0.150089         0.318283      0.071459
# target               0.281313  0.306958         0.472201      0.107542
#
# ...

# %%
df.head()
# Out:
#     age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0  40.0    1                2           140        289.0                    0
# 1  49.0    0                3           160        180.0                    0
# 2  37.0    1                2           130        283.0                    0
# 3  48.0    0                4           138        214.0                    0
# 4  54.0    1                3           150        195.0                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0           172.0                0      0.0         1       0
# 1            0           156.0                0      1.0         2       1
# 2            1            98.0                0      0.0         1       0
# 3            0           108.0                1      NaN         2       1
# 4            0           122.0                0      0.0         1       0

# %%
df[['age','sex']].corr() # correlation 30% er beshi moderate correlation ar 60% er beshi strong correlation
# Out:
#           age       sex
# age  1.000000  0.058049
# sex  0.058049  1.000000

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(kind = 'scatter',x ='cholesterol', y= 'max heart rate')
# Out:
# <Axes: xlabel='cholesterol', ylabel='max heart rate'>

# %%
df['age'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>
